# %% [markdown]
# # Car Features and MSRP_Project

# %% [markdown]
# Gathering Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading Dataset

# %%
data=pd.read_csv("C:/Users/Manoj Golla/Documents/EDA Project/Car Features and MSRP/data.csv")

# %%
#Have a general view of this dataframe.
data
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# ...                 ...               ...                ...              ...
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                              Market Category Vehicle Size  Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                         Luxury,Performance      Compact    Convertible
# 2                    Luxury,High-Performance      Compact          Coupe
# 3                         Luxury,Performance      Compact          Coupe
# 4                                     Luxury      Compact    Convertible
# ...                                      ...          ...            ...
# 11909             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11910             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11911             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11912             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11913                                 Luxury      Midsize          Sedan
#
#        highway MPG  city mpg  Popularity   MSRP
# 0               26        19        3916  46135
# 1               28        19        3916  40650
# 2               28        20        3916  36350
# 3               28        18        3916  29450
# 4               28        18        3916  34500
# ...            ...       ...         ...    ...
# 11909           23        16         204  46120
# 11910           23        16         204  56670
# 11911           23        16         204  50620
# 11912           23        16         204  50920
# 11913           26        17          61  28995
#
# [11914 rows x 16 columns]

# %%
#head()  will display the top 5 observations of the dataset
data.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
#tail() will display the last 5 observations of the dataset
data.tail()
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                   Market Category Vehicle Size  Vehicle Style  highway MPG  \
# 11909  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11910  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11911  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11912  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11913                      Luxury      Midsize          Sedan           26
#
#        city mpg  Popularity   MSRP
# 11909        16         204  46120
# 11910        16         204  56670
# 11911        16         204  50620
# 11912        16         204  50920
# 11913        17          61  28995

# %% [markdown]
# Checking the types of data

# %% [markdown]
# Here we check for the datatypes because sometimes the MSRP or the price of the car would be stored as a string, if in that case, we have to convert that string to the integer data only then we can plot the data via a graph. Here, in this case, the data is already in integer format so nothing to worry.

# %%
data.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %% [markdown]
# # Dropping irrelevant colomns

# %% [markdown]
# Renaming the columns

# %% [markdown]
# In this instance, most of the columns names are very confusing to read, so I just tweaked their columns names.

# %%
data = data.rename(columns={"Engine HP": "HP", "Engine Cylinders": "Cylinders", "Transmission Type": "Transmission", "Driven_Wheels": "Drive Mode","highway MPG": "MPG-H", "city mpg": "MPG-C", "MSRP": "Price" })
data.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type     HP  Cylinders  \
# 0  BMW  1 Series M  2011  premium unleaded (required)  335.0        6.0
# 1  BMW    1 Series  2011  premium unleaded (required)  300.0        6.0
# 2  BMW    1 Series  2011  premium unleaded (required)  300.0        6.0
# 3  BMW    1 Series  2011  premium unleaded (required)  230.0        6.0
# 4  BMW    1 Series  2011  premium unleaded (required)  230.0        6.0
#
#   Transmission        Drive Mode  Number of Doors  \
# 0       MANUAL  rear wheel drive              2.0
# 1       MANUAL  rear wheel drive              2.0
# 2       MANUAL  rear wheel drive              2.0
# 3       MANUAL  rear wheel drive              2.0
# 4       MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  MPG-H  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe     26
# 1                     Luxury,Performance      Compact   Convertible     28
# 2                Luxury,High-Performance      Compact         Coupe     28
# 3                     Luxury,Performance      Compact         Coupe     28
# 4                                 Luxury      Compact   Convertible     28
#
#    MPG-C  Popularity  Price
# 0     19        3916  46135
# 1     19        3916  40650
# 2     20        3916  36350
# 3     18        3916  29450
# 4     18        3916  34500

# %% [markdown]
# Dropping the duplicate rows-

# %% [markdown]
# This is often a handly thing to do because a huge dataset have some duplicate data which might be disturbing, so here I remove all duplicate values.¶

# %%
data.shape
# Out:
# (11914, 16)

# %%
data.size
# Out:
# 190624

# %%
# structuralInformation of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Make              11914 non-null  object
#  1   Model             11914 non-null  object
#  2   Year              11914 non-null  int64
#  3   Engine Fuel Type  11911 non-null  object
#  4   HP                11845 non-null  float64
#  5   Cylinders         11884 non-null  float64
#  6   Transmission      11914 non-null  object
#  7   Drive Mode        11914 non-null  object
#  8   Number of Doors   11908 non-null  float64
#  9   Market Category   8172 non-null   object
#  10  Vehicle Size      11914 non-null  object
#  11  Vehicle Style     11914 non-null  object
#  12  MPG-H             11914 non-null  int64
#  13  MPG-C             11914 non-null  int64
#  14  Popularity        11914 non-null  int64
#  15  Price             11914 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.5+ MB

# %%
# statistical information of the data
data.describe()
# Out:
#                Year           HP     Cylinders  Number of Doors         MPG-H  \
# count  11914.000000  11845.00000  11884.000000     11908.000000  11914.000000
# mean    2010.384338    249.38607      5.628829         3.436093     26.637485
# std        7.579740    109.19187      1.780559         0.881315      8.863001
# min     1990.000000     55.00000      0.000000         2.000000     12.000000
# 25%     2007.000000    170.00000      4.000000         2.000000     22.000000
# 50%     2015.000000    227.00000      6.000000         4.000000     26.000000
# 75%     2016.000000    300.00000      6.000000         4.000000     30.000000
# max     2017.000000   1001.00000     16.000000         4.000000    354.000000
#
#               MPG-C    Popularity         Price
# count  11914.000000  11914.000000  1.191400e+04
# mean      19.733255   1554.911197  4.059474e+04
# std        8.987798   1441.855347  6.010910e+04
# min        7.000000      2.000000  2.000000e+03
# 25%       16.000000    549.000000  2.100000e+04
# 50%       18.000000   1385.000000  2.999500e+04
# 75%       22.000000   2009.000000  4.223125e+04
# max      137.000000   5657.000000  2.065902e+06

# %%
# the continuous and categorical columns in the data. Duplicated data can be handled or removed based on further analysis
data.nunique()
# Out:
# Make                  48
# Model                915
# Year                  28
# Engine Fuel Type      10
# HP                   356
# Cylinders              9
# Transmission           5
# Drive Mode             4
# Number of Doors        3
# Market Category       71
# Vehicle Size           3
# Vehicle Style         16
# MPG-H                 59
# MPG-C                 69
# Popularity            48
# Price               6049
# dtype: int64

# %%
duplicate_rows_data = data[data.duplicated()]
print("number of duplicate rows: ", duplicate_rows_data.shape)
# Out:
# number of duplicate rows:  (715, 16)

# %%
# dropping duplicate rows
data = data.drop_duplicates()
data.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type     HP  Cylinders  \
# 0  BMW  1 Series M  2011  premium unleaded (required)  335.0        6.0
# 1  BMW    1 Series  2011  premium unleaded (required)  300.0        6.0
# 2  BMW    1 Series  2011  premium unleaded (required)  300.0        6.0
# 3  BMW    1 Series  2011  premium unleaded (required)  230.0        6.0
# 4  BMW    1 Series  2011  premium unleaded (required)  230.0        6.0
#
#   Transmission        Drive Mode  Number of Doors  \
# 0       MANUAL  rear wheel drive              2.0
# 1       MANUAL  rear wheel drive              2.0
# 2       MANUAL  rear wheel drive              2.0
# 3       MANUAL  rear wheel drive              2.0
# 4       MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  MPG-H  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe     26
# 1                     Luxury,Performance      Compact   Convertible     28
# 2                Luxury,High-Performance      Compact         Coupe     28
# 3                     Luxury,Performance      Compact         Coupe     28
# 4                                 Luxury      Compact   Convertible     28
#
#    MPG-C  Popularity  Price
# 0     19        3916  46135
# 1     19        3916  40650
# 2     20        3916  36350
# 3     18        3916  29450
# 4     18        3916  34500

# %%
data.tail()
# Out:
#           Make   Model  Year                Engine Fuel Type     HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)  300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)  300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)  300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)  300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded  221.0
#
#        Cylinders Transmission         Drive Mode  Number of Doors  \
# 11909        6.0    AUTOMATIC    all wheel drive              4.0
# 11910        6.0    AUTOMATIC    all wheel drive              4.0
# 11911        6.0    AUTOMATIC    all wheel drive              4.0
# 11912        6.0    AUTOMATIC    all wheel drive              4.0
# 11913        6.0    AUTOMATIC  front wheel drive              4.0
#
#                   Market Category Vehicle Size  Vehicle Style  MPG-H  MPG-C  \
# 11909  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback     23     16
# 11910  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback     23     16
# 11911  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback     23     16
# 11912  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback     23     16
# 11913                      Luxury      Midsize          Sedan     26     17
#
#        Popularity  Price
# 11909         204  46120
# 11910         204  56670
# 11911         204  50620
# 11912         204  50920
# 11913          61  28995

# %% [markdown]
# # Missing or null values

# %% [markdown]
# This approach is not to do good so, beacause many people just replace the missing values with the mean or the average of that columns.

# %%
print(data.isnull().sum())
# Out:
# Make                   0
# Model                  0
# Year                   0
# Engine Fuel Type       3
# HP                    69
# Cylinders             30
# Transmission           0
# Drive Mode             0
# Number of Doors        6
# Market Category     3376
# Vehicle Size           0
# Vehicle Style          0
# MPG-H                  0
# MPG-C                  0
# Popularity             0
# Price                  0
# dtype: int64

# %% [markdown]
# Here we can see the both cylinders and HP had less count.Therefore dropping the missing values.

# %%
data = data.dropna()              # dropping the values
data.count()
# Out:
# Make                7735
# Model               7735
# Year                7735
# Engine Fuel Type    7735
# HP                  7735
# Cylinders           7735
# Transmission        7735
# Drive Mode          7735
# Number of Doors     7735
# Market Category     7735
# Vehicle Size        7735
# Vehicle Style       7735
# MPG-H               7735
# MPG-C               7735
# Popularity          7735
# Price               7735
# dtype: int64

# %%
print(data.isnull().sum())       # after dropping the values
# Out:
# Make                0
# Model               0
# Year                0
# Engine Fuel Type    0
# HP                  0
# Cylinders           0
# Transmission        0
# Drive Mode          0
# Number of Doors     0
# Market Category     0
# Vehicle Size        0
# Vehicle Style       0
# MPG-H               0
# MPG-C               0
# Popularity          0
# Price               0
# dtype: int64

# %% [markdown]
# # Data Reduction

# %%
# Remove Make column from data
data = data.drop(['Make'], axis = 1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7735 entries, 0 to 11913
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Model             7735 non-null   object
#  1   Year              7735 non-null   int64
#  2   Engine Fuel Type  7735 non-null   object
#  3   HP                7735 non-null   float64
#  4   Cylinders         7735 non-null   float64
#  5   Transmission      7735 non-null   object
#  6   Drive Mode        7735 non-null   object
#  7   Number of Doors   7735 non-null   float64
#  8   Market Category   7735 non-null   object
#  9   Vehicle Size      7735 non-null   object
#  10  Vehicle Style     7735 non-null   object
#  11  MPG-H             7735 non-null   int64
#  12  MPG-C             7735 non-null   int64
#  13  Popularity        7735 non-null   int64
#  14  Price             7735 non-null   int64
# dtypes: float64(3), int64(5), object(7)
# memory usage: 966.9+ KB

# %% [markdown]
# # Creating Features

# %%
from datetime import date
date.today().year
data['Car_Age']=date.today().year-data['Year']
data.head()
# Out:
#         Model  Year             Engine Fuel Type     HP  Cylinders  \
# 0  1 Series M  2011  premium unleaded (required)  335.0        6.0
# 1    1 Series  2011  premium unleaded (required)  300.0        6.0
# 2    1 Series  2011  premium unleaded (required)  300.0        6.0
# 3    1 Series  2011  premium unleaded (required)  230.0        6.0
# 4    1 Series  2011  premium unleaded (required)  230.0        6.0
#
#   Transmission        Drive Mode  Number of Doors  \
# 0       MANUAL  rear wheel drive              2.0
# 1       MANUAL  rear wheel drive              2.0
# 2       MANUAL  rear wheel drive              2.0
# 3       MANUAL  rear wheel drive              2.0
# 4       MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  MPG-H  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe     26
# 1                     Luxury,Performance      Compact   Convertible     28
# 2                Luxury,High-Performance      Compact         Coupe     28
# 3                     Luxury,Performance      Compact         Coupe     28
# 4                                 Luxury      Compact   Convertible     28
#
#    MPG-C  Popularity  Price  Car_Age
# 0     19        3916  46135       11
# 1     19        3916  40650       11
# 2     20        3916  36350       11
# 3     18        3916  29450       11
# 4     18        3916  34500       11

# %% [markdown]
# # Data Cleaning/Wrangling

# %%
#Let's see whether there are duplicated tweet id.
data[data.Year.duplicated()]
# Out:
#           Model  Year                Engine Fuel Type     HP  Cylinders  \
# 1      1 Series  2011     premium unleaded (required)  300.0        6.0
# 2      1 Series  2011     premium unleaded (required)  300.0        6.0
# 3      1 Series  2011     premium unleaded (required)  230.0        6.0
# 4      1 Series  2011     premium unleaded (required)  230.0        6.0
# 6      1 Series  2012     premium unleaded (required)  300.0        6.0
# ...         ...   ...                             ...    ...        ...
# 11909       ZDX  2012     premium unleaded (required)  300.0        6.0
# 11910       ZDX  2012     premium unleaded (required)  300.0        6.0
# 11911       ZDX  2012     premium unleaded (required)  300.0        6.0
# 11912       ZDX  2013  premium unleaded (recommended)  300.0        6.0
# 11913    Zephyr  2006                regular unleaded  221.0        6.0
#
#       Transmission         Drive Mode  Number of Doors  \
# 1           MANUAL   rear wheel drive              2.0
# 2           MANUAL   rear wheel drive              2.0
# 3           MANUAL   rear wheel drive              2.0
# 4           MANUAL   rear wheel drive              2.0
# 6           MANUAL   rear wheel drive              2.0
# ...            ...                ...              ...
# 11909    AUTOMATIC    all wheel drive              4.0
# 11910    AUTOMATIC    all wheel drive              4.0
# 11911    AUTOMATIC    all wheel drive              4.0
# 11912    AUTOMATIC    all wheel drive              4.0
# 11913    AUTOMATIC  front wheel drive              4.0
#
#                   Market Category Vehicle Size  Vehicle Style  MPG-H  MPG-C  \
# 1              Luxury,Performance      Compact    Convertible     28     19
# 2         Luxury,High-Performance      Compact          Coupe     28     20
# 3              Luxury,Performance      Compact          Coupe     28     18
# 4                          Luxury      Compact    Convertible     28     18
# 6              Luxury,Performance      Compact    Convertible     26     17
# ...                           ...          ...            ...    ...    ...
# 11909  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback     23     16
# 11910  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback     23     16
# 11911  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback     23     16
# 11912  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback     23     16
# 11913                      Luxury      Midsize          Sedan     26     17
#
#        Popularity  Price  Car_Age
# 1            3916  40650       11
# 2            3916  36350       11
# 3            3916  29450       11
# 4            3916  34500       11
# 6            3916  44100       10
# ...           ...    ...      ...
# 11909         204  46120       10
# 11910         204  56670       10
# 11911         204  50620       10
# 11912         204  50920        9
# 11913          61  28995       16
#
# [7707 rows x 16 columns]

# %%
data.Year.value_counts()
# Out:
# 2016    1624
# 2015    1613
# 2017    1243
# 2014     477
# 2012     279
# 2013     277
# 2009     271
# 2011     229
# 2007     222
# 2010     217
# 2008     185
# 2006     102
# 2005      92
# 2004      91
# 2003      88
# 1993      80
# 1992      71
# 2002      71
# 2001      66
# 2000      59
# 1997      57
# 1994      57
# 1991      55
# 1995      51
# 1996      48
# 1999      45
# 1990      34
# 1998      31
# Name: Year, dtype: int64

# %%
data.Popularity.value_counts()
# Out:
# 1385    608
# 5657    485
# 873     411
# 1624    396
# 617     340
# 190     328
# 3916    324
# 3105    321
# 2009    308
# 1851    298
# 2031    295
# 549     270
# 2202    269
# 870     266
# 204     246
# 586     234
# 454     202
# 640     197
# 1439    190
# 61      152
# 258     139
# 1715    136
# 155     125
# 436     120
# 376     109
# 1720    109
# 1013    108
# 481      96
# 259      91
# 210      77
# 520      74
# 2774     68
# 238      55
# 1158     52
# 105      48
# 819      38
# 535      37
# 86       31
# 613      28
# 130      17
# 67       16
# 416       5
# 113       5
# 820       3
# 21        3
# 26        3
# 2         2
# Name: Popularity, dtype: int64

# %%
data.Price.value_counts()
# Out:
# 2000     307
# 29995     16
# 25995     14
# 24995     11
# 43950     10
#         ...
# 18960      1
# 23170      1
# 17170      1
# 18515      1
# 50920      1
# Name: Price, Length: 4644, dtype: int64

# %% [markdown]
# # Detecting outliers

# %% [markdown]
# It is good to detect and remove the outliers, because outliers are one of the primary reason for resulting in a less accurate model.

# %%
sns.boxplot(x=data['Price'])
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
sns.boxplot(x=data['HP'])
# Out:
# <AxesSubplot:xlabel='HP'>

# %%
sns.boxplot(x=data['Cylinders'])
# Out:
# <AxesSubplot:xlabel='Cylinders'>

# %% [markdown]
# Now I'm going to perform is called Interquartile range(IQR) score technique.

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Year                   6.0
# HP                   131.0
# Cylinders              2.0
# Number of Doors        2.0
# MPG-H                  8.0
# MPG-C                  6.0
# Popularity          1489.0
# Price              23252.5
# Car_Age                6.0
# dtype: float64

# %% [markdown]
# # Data visualization using scatter and histogram

# %% [markdown]
# Histogram-

# %% [markdown]
# Histogram is one of the best solution which lets us know the total Number of car manufactured.

# %%
data.Model.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Number of cars by make")
plt.ylabel('Number of cars')
plt.xlabel('Model');

# %% [markdown]
# Scatter plot-

# %% [markdown]
# To find the correlation between two variables.

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(data['HP'], data['Price'])
ax.set_xlabel('HP')
ax.set_ylabel('Price')
plt.show()

# %% [markdown]
#  Heatmap-

# %%
plt.figure(figsize=(10,5))
c = data.corr()
sns.heatmap(c, cmap="BrBG", annot=True )
# Out:
# <AxesSubplot:>
